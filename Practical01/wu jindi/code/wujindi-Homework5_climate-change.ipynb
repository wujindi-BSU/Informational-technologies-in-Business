# %%
# %pip install pandas matplotlib numpy pathlib pingouin lets_plot
# Out:
# Requirement already satisfied: pandas in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.9.2)
# Requirement already satisfied: numpy in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.26.4)
# Requirement already satisfied: pathlib in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.0.1)
# Requirement already satisfied: pingouin in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.5.5)
# Requirement already satisfied: lets_plot in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (4.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: pandas-flavor in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pingouin) (0.6.0)
# Requirement already satisfied: scikit-learn>=1.2 in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pingouin) (1.5.2)
# Requirement already satisfied: scipy in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pingouin) (1.14.1)
# Requirement already satisfied: seaborn in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pingouin) (0.13.2)
# Requirement already satisfied: statsmodels in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pingouin) (0.14.4)
# Requirement already satisfied: tabulate in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pingouin) (0.9.0)
# Requirement already satisfied: pypng in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from lets_plot) (0.20220715.0)
# Requirement already satisfied: palettable in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from lets_plot) (3.3.3)
# Requirement already satisfied: six>=1.5 in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn>=1.2->pingouin) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn>=1.2->pingouin) (3.5.0)
# Requirement already satisfied: xarray in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas-flavor->pingouin) (2024.10.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\wujinzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from statsmodels->pingouin) (0.5.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: C:\Users\wujinzi\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
#import pingouin as pg
from lets_plot import *

LetsPlot.setup_html(no_js=True)

### You don't need to use these settings yourself,
### they are just here to make the charts look nicer!
# Set the plot style for prettier charts:
plt.style.use(
    "https://raw.githubusercontent.com/aeturrell/core_python/main/plot_style.txt"
)

# %% [markdown]
# Questions:Explain in your own words what temperature ‘anomalies’ are. Why have researchers chosen this particular measure over other measures (such as absolute temperature)?

# %% [markdown]
# The answer:
#
# (1)A temperature "anomaly" is typically defined as a temperature that falls outside the normal range or expected value, suggesting the potential for an underlying issue or change. In contrast, absolute temperature represents the average kinetic energy of molecular motion and is expressed in Kelvins (K).
# (2)Researchers select temperature "anomalies" over absolute temperatures due to their greater practicality, intuitiveness, ease of comprehension, suitability for comparison with normal conditions, and adaptability to diverse research fields and objectives.

# %%
df = pd.read_csv(
    "https://data.giss.nasa.gov/gistemp/tabledata_v4/NH.Ts+dSST.csv",
    skiprows=1,
    na_values="***",
)

# %%
df.head()
# Out:
#    Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0  1880 -0.39 -0.54 -0.24 -0.31 -0.06 -0.18 -0.22 -0.26 -0.25 -0.31 -0.44
# 1  1881 -0.31 -0.25 -0.06 -0.02  0.05 -0.34  0.09 -0.06 -0.29 -0.45 -0.37
# 2  1882  0.26  0.21  0.02 -0.30 -0.23 -0.29 -0.28 -0.15 -0.25 -0.52 -0.34
# 3  1883 -0.58 -0.66 -0.15 -0.30 -0.26 -0.12 -0.06 -0.23 -0.34 -0.17 -0.45
# 4  1884 -0.16 -0.11 -0.64 -0.59 -0.36 -0.42 -0.41 -0.52 -0.45 -0.45 -0.58
#
#     Dec   J-D   D-N   DJF   MAM   JJA   SON
# 0 -0.43 -0.30   NaN   NaN -0.20 -0.22 -0.33
# 1 -0.23 -0.19 -0.20 -0.33 -0.01 -0.10 -0.37
# 2 -0.69 -0.21 -0.18  0.08 -0.17 -0.24 -0.37
# 3 -0.15 -0.29 -0.33 -0.64 -0.24 -0.14 -0.32
# 4 -0.47 -0.43 -0.40 -0.14 -0.53 -0.45 -0.50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    145 non-null    int64
#  1   Jan     145 non-null    float64
#  2   Feb     145 non-null    float64
#  3   Mar     145 non-null    float64
#  4   Apr     145 non-null    float64
#  5   May     145 non-null    float64
#  6   Jun     145 non-null    float64
#  7   Jul     145 non-null    float64
#  8   Aug     145 non-null    float64
#  9   Sep     145 non-null    float64
#  10  Oct     144 non-null    float64
#  11  Nov     144 non-null    float64
#  12  Dec     144 non-null    float64
#  13  J-D     144 non-null    float64
#  14  D-N     143 non-null    float64
#  15  DJF     144 non-null    float64
#  16  MAM     145 non-null    float64
#  17  JJA     145 non-null    float64
#  18  SON     144 non-null    float64
# dtypes: float64(18), int64(1)
# memory usage: 21.7 KB

# %%
df = pd.read_csv("https://data.giss.nasa.gov/gistemp/tabledata_v4/NH.Ts+dSST.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 146 entries, ('Year', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'J-D', 'D-N', 'DJF', 'MAM', 'JJA') to ('2024', '1.66', '1.93', '1.77', '1.79', '1.44', '1.54', '1.42', '1.42', '1.57', '***', '***', '***', '***', '***', '1.81', '1.67', '1.46')
# Data columns (total 1 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Land-Ocean: Northern Hemispheric Means  146 non-null    object
# dtypes: object(1)
# memory usage: 71.2+ KB

# %%
print(df.head())
# Out:
#                                                                                           Land-Ocean: Northern Hemispheric Means
# Year Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec  J-D  D-N  DJF  MAM  JJA                                     SON
# 1880 -.39 -.54 -.24 -.31 -.06 -.18 -.22 -.26 -.25 -.31 -.44 -.43 -.30 ***  ***  -.20 -.22                                   -.33
# 1881 -.31 -.25 -.06 -.02 .05  -.34 .09  -.06 -.29 -.45 -.37 -.23 -.19 -.20 -.33 -.01 -.10                                   -.37
# 1882 .26  .21  .02  -.30 -.23 -.29 -.28 -.15 -.25 -.52 -.34 -.69 -.21 -.18 .08  -.17 -.24                                   -.37
# 1883 -.58 -.66 -.15 -.30 -.26 -.12 -.06 -.23 -.34 -.17 -.45 -.15 -.29 -.33 -.64 -.24 -.14                                   -.32

# %% [markdown]
# Questions:Try importing the data again without using the keyword argument option na_values="***" at all and see what difference it makes.

# %% [markdown]
# The answer: By comparing the output of.info(), you can see the difference in importing the data without parameters. Some columns may be recognized as object instead of float64 or int64, which usually means they contain non-numeric characters.

# %%
df = pd.read_csv(
    "https://data.giss.nasa.gov/gistemp/tabledata_v4/NH.Ts+dSST.csv",
    skiprows=1,
    na_values="***",
)

# %%
df.head()
# Out:
#    Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0  1880 -0.39 -0.54 -0.24 -0.31 -0.06 -0.18 -0.22 -0.26 -0.25 -0.31 -0.44
# 1  1881 -0.31 -0.25 -0.06 -0.02  0.05 -0.34  0.09 -0.06 -0.29 -0.45 -0.37
# 2  1882  0.26  0.21  0.02 -0.30 -0.23 -0.29 -0.28 -0.15 -0.25 -0.52 -0.34
# 3  1883 -0.58 -0.66 -0.15 -0.30 -0.26 -0.12 -0.06 -0.23 -0.34 -0.17 -0.45
# 4  1884 -0.16 -0.11 -0.64 -0.59 -0.36 -0.42 -0.41 -0.52 -0.45 -0.45 -0.58
#
#     Dec   J-D   D-N   DJF   MAM   JJA   SON
# 0 -0.43 -0.30   NaN   NaN -0.20 -0.22 -0.33
# 1 -0.23 -0.19 -0.20 -0.33 -0.01 -0.10 -0.37
# 2 -0.69 -0.21 -0.18  0.08 -0.17 -0.24 -0.37
# 3 -0.15 -0.29 -0.33 -0.64 -0.24 -0.14 -0.32
# 4 -0.47 -0.43 -0.40 -0.14 -0.53 -0.45 -0.50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    145 non-null    int64
#  1   Jan     145 non-null    float64
#  2   Feb     145 non-null    float64
#  3   Mar     145 non-null    float64
#  4   Apr     145 non-null    float64
#  5   May     145 non-null    float64
#  6   Jun     145 non-null    float64
#  7   Jul     145 non-null    float64
#  8   Aug     145 non-null    float64
#  9   Sep     145 non-null    float64
#  10  Oct     144 non-null    float64
#  11  Nov     144 non-null    float64
#  12  Dec     144 non-null    float64
#  13  J-D     144 non-null    float64
#  14  D-N     143 non-null    float64
#  15  DJF     144 non-null    float64
#  16  MAM     145 non-null    float64
#  17  JJA     145 non-null    float64
#  18  SON     144 non-null    float64
# dtypes: float64(18), int64(1)
# memory usage: 21.7 KB

# %%
df = df.set_index("Year")
df.head()
# Out:
#        Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec  \
# Year
# 1880 -0.39 -0.54 -0.24 -0.31 -0.06 -0.18 -0.22 -0.26 -0.25 -0.31 -0.44 -0.43
# 1881 -0.31 -0.25 -0.06 -0.02  0.05 -0.34  0.09 -0.06 -0.29 -0.45 -0.37 -0.23
# 1882  0.26  0.21  0.02 -0.30 -0.23 -0.29 -0.28 -0.15 -0.25 -0.52 -0.34 -0.69
# 1883 -0.58 -0.66 -0.15 -0.30 -0.26 -0.12 -0.06 -0.23 -0.34 -0.17 -0.45 -0.15
# 1884 -0.16 -0.11 -0.64 -0.59 -0.36 -0.42 -0.41 -0.52 -0.45 -0.45 -0.58 -0.47
#
#        J-D   D-N   DJF   MAM   JJA   SON
# Year
# 1880 -0.30   NaN   NaN -0.20 -0.22 -0.33
# 1881 -0.19 -0.20 -0.33 -0.01 -0.10 -0.37
# 1882 -0.21 -0.18  0.08 -0.17 -0.24 -0.37
# 1883 -0.29 -0.33 -0.64 -0.24 -0.14 -0.32
# 1884 -0.43 -0.40 -0.14 -0.53 -0.45 -0.50

# %%
df.tail()
# Out:
#        Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec  \
# Year
# 2020  1.58  1.69  1.66  1.39  1.26  1.14  1.10  1.12  1.19  1.20  1.58  1.18
# 2021  1.25  0.95  1.20  1.12  1.04  1.20  1.07  1.02  1.04  1.29  1.29  1.16
# 2022  1.24  1.16  1.41  1.08  1.02  1.12  1.06  1.16  1.14  1.31  1.09  1.06
# 2023  1.29  1.29  1.63  1.01  1.12  1.19  1.44  1.57  1.67  1.88  1.97  1.85
# 2024  1.66  1.93  1.77  1.79  1.44  1.54  1.42  1.42  1.57   NaN   NaN   NaN
#
#        J-D   D-N   DJF   MAM   JJA   SON
# Year
# 2020  1.34  1.36  1.56  1.44  1.12  1.32
# 2021  1.14  1.14  1.13  1.12  1.10  1.21
# 2022  1.15  1.16  1.19  1.17  1.11  1.18
# 2023  1.49  1.43  1.21  1.26  1.40  1.84
# 2024   NaN   NaN  1.81  1.67  1.46   NaN

# %%
fig, ax = plt.subplots()
df["Jan"].plot(ax=ax)
ax.set_ylabel("y label")
ax.set_xlabel("x label")
ax.set_title("title")
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(df.index, df["Jan"])
ax.set_ylabel("y label")
ax.set_xlabel("x label")
ax.set_title("title")
plt.show()

# %%
plt.show()

# %%
plt.savefig("name-of-chart.pdf")

# %%
month = "Jan"
fig, ax = plt.subplots()
ax.axhline(0, color="orange")
ax.annotate("1951—1980 average", xy=(0.66, -0.2), xycoords=("figure fraction", "data"))
df[month].plot(ax=ax)
ax.set_title(
    f"Average temperature anomaly in {month} \n in the northern hemisphere (1880—{df.index.max()})"
)
ax.set_ylabel("Annual temperature anomalies");

# %% [markdown]
# Extra practice:Extra practice: The columns labelled DJF, MAM, JJA, and SON contain seasonal averages (means). For example, the MAM column contains the average of the March, April, and May columns for each year. Plot a separate line chart for each season, using average temperature anomaly for that season on the vertical axis and time (from 1880 to the latest year available) on the horizontal axis.

# %% [markdown]
# The answer:

# %%
month = "Jan"
fig, ax = plt.subplots()
ax.axhline(0, color="red")
ax.annotate("1951—1980 average",  xy=(1.96, -1.5),xycoords=("figure fraction", "data"))
df[month].plot(ax=ax)
ax.set_title(
    f"Average temperature anomaly in {month} \n in the northern hemisphere (1880—{df.index.max()})"
)
ax.set_ylabel("Annual temperature anomalies");

# %%
month = "MAM"
fig, ax = plt.subplots()
ax.axhline(0, color="orange")
ax.annotate("1951—1980 average", xy=(0.66, -0.2), xycoords=("figure fraction", "data"))
df[month].plot(ax=ax)
ax.set_title(
    f"Average temperature anomaly in {month} \n in the northern hemisphere (1880—{df.index.max()})"
)
ax.set_ylabel("Annual temperature anomalies");

# %%
month = "JJA"
fig, ax = plt.subplots()
ax.axhline(0, color="orange")
ax.annotate("1951—1980 average", xy=(0.66, -0.2), xycoords=("figure fraction", "data"))
df[month].plot(ax=ax)
ax.set_title(
    f"Average temperature anomaly in {month} \n in the northern hemisphere (1880—{df.index.max()})"
)
ax.set_ylabel("Annual temperature anomalies");

# %% [markdown]
# Questions:What do your charts from Questions 2 to 4(a) suggest about the relationship between temperature and time?

# %% [markdown]
# The answer: Temperature increases with time.

# %%
month = "J-D"
fig, ax = plt.subplots()
ax.axhline(0, color="orange")
ax.annotate("1951—1980 average", xy=(0.68, -0.2), xycoords=("figure fraction", "data"))
df[month].plot(ax=ax)
ax.set_title(
    f"Average annual temperature anomaly in \n in the northern hemisphere (1880—{df.index.max()})"
)
ax.set_ylabel("Annual temperature anomalies");

# %% [markdown]
# Questions:Discuss the similarities and differences between the charts. (For example, are the horizontal and vertical axes variables the same, or do the lines have the same shape?)
# The answer:
# (1)Similaritie:The temperature changes with time, and the overall trend is upward.
# (2)Differences:The horizontal and vertical axis variables of the two tables are different. For example, in 2000, Figure 1.4 shows a temperature of 0.5 and Figure 1.5 shows a temperature of 0.6.
#
# Questions:Looking at the behaviour of temperature over time from 1000 to 1900 in Figure 1.4, are the observed patterns in your chart unusual?
# The answer:From 1000 to 1900, the temperature fluctuate up and down with time, but the maximum value did not exceed 0.0, which indicates that the temperature change during this period was relatively small compared to the significant increase in industrial temperature after 1900, which I think is normal.
#
# Questions:Based on your answers to Questions 4 and 5, do you think the government should be concerned about climate change?
# The answer:My point of view is that according to the chart data, the temperature is rising, which is a sign of global warming, so the government should pay attention to climate change.

# %%
df["Period"] = pd.cut(
    df.index,
    bins=[1921, 1950, 1980, 2010],
    labels=["1921—1950", "1951—1980", "1981—2010"],
    ordered=True,
)

# %%
df["Period"].tail(20)
# Out:
# Year
# 2005    1981—2010
# 2006    1981—2010
# 2007    1981—2010
# 2008    1981—2010
# 2009    1981—2010
# 2010    1981—2010
# 2011          NaN
# 2012          NaN
# 2013          NaN
# 2014          NaN
# 2015          NaN
# 2016          NaN
# 2017          NaN
# 2018          NaN
# 2019          NaN
# 2020          NaN
# 2021          NaN
# 2022          NaN
# 2023          NaN
# 2024          NaN
# Name: Period, dtype: category
# Categories (3, object): ['1921—1950' < '1951—1980' < '1981—2010']

# %%
list_of_months = ["Jun", "Jul", "Aug"]
df[list_of_months].stack().head()
# Out:
# Year
# 1880  Jun   -0.18
#       Jul   -0.22
#       Aug   -0.26
# 1881  Jun   -0.34
#       Jul    0.09
# dtype: float64

# %%
fig, axes = plt.subplots(ncols=3, figsize=(9, 4), sharex=True, sharey=True)
for ax, period in zip(axes, df["Period"].dropna().unique()):
    df.loc[df["Period"] == period, list_of_months].stack().hist(ax=ax)
    ax.set_title(period)
plt.suptitle("Histogram of temperature anomalies")
axes[1].set_xlabel("Summer temperature distribution")
plt.tight_layout();

# %%
# Create a variable that has years 1951 to 1980, and months Jan to Dec (inclusive)
temp_all_months = df.loc[(df.index >= 1951) & (df.index <= 1980), "Jan":"Dec"]
# Put all the data in stacked format and give the new columns sensible names
temp_all_months = (
    temp_all_months.stack()
    .reset_index()
    .rename(columns={"level_1": "month", 0: "values"})
)
# Take a look at this data:
temp_all_months
# Out:
#      Year month  values
# 0    1951   Jan   -0.36
# 1    1951   Feb   -0.51
# 2    1951   Mar   -0.19
# 3    1951   Apr    0.07
# 4    1951   May    0.17
# ..    ...   ...     ...
# 355  1980   Aug    0.09
# 356  1980   Sep    0.10
# 357  1980   Oct    0.12
# 358  1980   Nov    0.20
# 359  1980   Dec    0.09
#
# [360 rows x 3 columns]

# %%
quantiles = [0.3, 0.7]
list_of_percentiles = np.quantile(temp_all_months["values"], q=quantiles)

print(f"The cold threshold of {quantiles[0]*100}% is {list_of_percentiles[0]}")
print(f"The hot threshold of {quantiles[1]*100}% is {list_of_percentiles[1]}")
# Out:
# The cold threshold of 30.0% is -0.1
# The hot threshold of 70.0% is 0.1

# %%
# Create a variable that has years 1981 to 2010, and months Jan to Dec (inclusive)
temp_all_months = df.loc[(df.index >= 1981) & (df.index <= 2010), "Jan":"Dec"]
# Put all the data in stacked format and give the new columns sensible names
temp_all_months = (
    temp_all_months.stack()
    .reset_index()
    .rename(columns={"level_1": "month", 0: "values"})
)
# Take a look at the start of this data data:
temp_all_months.head()
# Out:
#    Year month  values
# 0  1981   Jan    0.79
# 1  1981   Feb    0.62
# 2  1981   Mar    0.68
# 3  1981   Apr    0.39
# 4  1981   May    0.18

# %%
entries_less_than_q30 = temp_all_months["values"] < list_of_percentiles[0]
proportion_under_q30 = entries_less_than_q30.mean()
print(
    f"The proportion under {list_of_percentiles[0]} is {proportion_under_q30*100:.2f}%"
)
# Out:
# The proportion under -0.1 is 1.94%

# %%
proportion_over_q70 = (temp_all_months["values"] > list_of_percentiles[1]).mean()
print(f"The proportion over {list_of_percentiles[1]} is {proportion_over_q70*100:.2f}%")
# Out:
# The proportion over 0.1 is 84.72%

# %%
temp_all_months = (
    df.loc[:, "DJF":"SON"]
    .stack()
    .reset_index()
    .rename(columns={"level_1": "Season", 0: "Values"})
)
temp_all_months["Period"] = pd.cut(
    temp_all_months["Year"],
    bins=[1921, 1950, 1980, 2010],
    labels=["1921—1950", "1951—1980", "1981—2010"],
    ordered=True,
)
# Take a look at a cut of the data using `.iloc`, which provides position
temp_all_months.iloc[-135:-125]
# Out:
#      Year Season  Values     Period
# 443  1991    DJF    0.51  1981—2010
# 444  1991    MAM    0.45  1981—2010
# 445  1991    JJA    0.42  1981—2010
# 446  1991    SON    0.32  1981—2010
# 447  1992    DJF    0.43  1981—2010
# 448  1992    MAM    0.30  1981—2010
# 449  1992    JJA   -0.04  1981—2010
# 450  1992    SON   -0.15  1981—2010
# 451  1993    DJF    0.37  1981—2010
# 452  1993    MAM    0.31  1981—2010

# %% [markdown]
# Questions:Calculate the mean (average) and variance separately for the following time periods: 1921–1950, 1951–1980, and 1981–2010.

# %% [markdown]
# The answer:The variance of the later period is significantly higher than that of the earlier period, which indicates that the air temperature becomes more variable.

# %%
seasons = {
    "DJF": ["Dec", "Jan", "Feb"],
    "MAM": ["Mar", "Apr", "May"],
    "JJA": ["Jun", "Jul", "Aug"],
    "SON": ["Sep", "Oct", "Nov"]
}

# %%
for season, months in seasons.items():
    if all(month in df.columns for month in months):
        df[season] = df[months].mean(axis=1)

# %%
periods = {
    "1921-1950": (1921, 1950),
    "1951-1980": (1951, 1980),
    "1981-2010": (1981, 2010)
}

# %%
results = {}
for season in seasons.keys():
    if season in df.columns:
        results[season] = {}
        for period, (start_year, end_year) in periods.items():
            period_data = df.loc[start_year:end_year, season]
            results[season][period] = {
                "mean": period_data.mean(),
                "variance": period_data.var(),
            }

# %%
for season, period_results in results.items():
    print(f"Season: {season}")
    for period, stats in period_results.items():
        print(f"  Period: {period}")
        print(f"    Mean: {stats['mean']:.2f}")
        print(f"    Variance: {stats['variance']:.2f}")
    print()
# Out:
# Season: DJF
#   Period: 1921-1950
#     Mean: -0.03
#     Variance: 0.05
#   Period: 1951-1980
#     Mean: 0.00
#     Variance: 0.04
#   Period: 1981-2010
#     Mean: 0.53
#     Variance: 0.07
#
# Season: MAM
#   Period: 1921-1950
#     Mean: -0.05
#     Variance: 0.03
#   Period: 1951-1980
#     Mean: -0.00
#     Variance: 0.03
#   Period: 1981-2010
#     Mean: 0.51
#     Variance: 0.08
#
# Season: JJA
#   Period: 1921-1950
#     Mean: -0.06
#     Variance: 0.02
#   Period: 1951-1980
#     Mean: 0.00
#     Variance: 0.01
#   Period: 1981-2010
#     Mean: 0.40
#     Variance: 0.07
#
# Season: SON
#   Period: 1921-1950
#     Mean: 0.07
#     Variance: 0.03
#   Period: 1951-1980
#     Mean: -0.00
#     Variance: 0.03
#   Period: 1981-2010
#     Mean: 0.43
#     Variance: 0.11

# %%
temp_all_months = (
    df.loc[:, "DJF":"SON"]
    .stack()
    .reset_index()
    .rename(columns={"level_1": "Season", 0: "Values"})
)
temp_all_months["Period"] = pd.cut(
    temp_all_months["Year"],
    bins=[1921, 1950, 1980, 2010],
    labels=["1921—1950", "1951—1980", "1981—2010"],
    ordered=True,
)
# Take a look at a cut of the data using `.iloc`, which provides position
temp_all_months.iloc[-135:-125]
# Out:
#      Year Season    Values     Period
# 445  1991    MAM  0.450000  1981—2010
# 446  1991    JJA  0.416667  1981—2010
# 447  1991    SON  0.320000  1981—2010
# 448  1992    DJF  0.440000  1981—2010
# 449  1992    MAM  0.296667  1981—2010
# 450  1992    JJA -0.043333  1981—2010
# 451  1992    SON -0.146667  1981—2010
# 452  1993    DJF  0.376667  1981—2010
# 453  1993    MAM  0.310000  1981—2010
# 454  1993    JJA  0.120000  1981—2010

# %%
grp_mean_var = temp_all_months.groupby(["Season", "Period"])["Values"].agg(
    [np.mean, np.var]
)
grp_mean_var
# Out:
# C:\Users\wujinzi\AppData\Local\Temp\ipykernel_12160\1563140002.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grp_mean_var = temp_all_months.groupby(["Season", "Period"])["Values"].agg(
# C:\Users\wujinzi\AppData\Local\Temp\ipykernel_12160\1563140002.py:1: FutureWarning: The provided callable <function mean at 0x000001F7459D6D40> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   grp_mean_var = temp_all_months.groupby(["Season", "Period"])["Values"].agg(
# C:\Users\wujinzi\AppData\Local\Temp\ipykernel_12160\1563140002.py:1: FutureWarning: The provided callable <function var at 0x000001F7459D6FC0> is currently using SeriesGroupBy.var. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "var" instead.
#   grp_mean_var = temp_all_months.groupby(["Season", "Period"])["Values"].agg(
#                       mean       var
# Season Period
# DJF    1921—1950 -0.028046  0.051446
#        1951—1980  0.000333  0.037331
#        1981—2010  0.526444  0.072318
# JJA    1921—1950 -0.053908  0.021486
#        1951—1980  0.000111  0.014556
#        1981—2010  0.397778  0.067365
# MAM    1921—1950 -0.042184  0.031097
#        1951—1980 -0.000111  0.025510
#        1981—2010  0.507667  0.075556
# SON    1921—1950  0.080920  0.027859
#        1951—1980 -0.000222  0.026034
#        1981—2010  0.427222  0.110288

# %%
min_year = 1880
(
    ggplot(temp_all_months, aes(x="Year", y="Values", color="Season"))
    + geom_abline(slope=0, color="black", size=1)
    + geom_line(size=1)
    + labs(
        title=f"Average annual temperature anomaly in \n in the northern hemisphere ({min_year}—{temp_all_months['Year'].max()})",
        y="Annual temperature anomalies",
    )
    + scale_x_continuous(format="d")
    + geom_text(
        x=min_year, y=0.1, label="1951—1980 average", hjust="left", color="black"
    )
)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #poBi5tG .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #poBi5tG .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #poBi5tG .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #poBi5tG .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# #poBi5tG .legend-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #poBi5tG .legend-item {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #poBi5tG .axis-title-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #poBi5tG .axis-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dz0J6Ye .axis-tooltip-text-x {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #poBi5tG .axis-title-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #poBi5tG .axis-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dz0J6Ye .axis-tooltip-text-y {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #poBi5tG .facet-strip-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #poBi5tG .facet-strip-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dz0J6Ye .tooltip-text {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dz0J6Ye .tooltip-title {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dz0J6Ye .tooltip-label {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
#
#   </style>
#   <g id="poBi5tG">
#     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
#     </path>
#     <g transform="translate(29.5 42.5 ) ">
#       <g>
#         <g transform="translate(35.01530667574961 0.0 ) ">
#           <g>
#             <line x1="20.292512015615102" y1="0.0" x2="20.292512015615102" y2="305.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="76.66060094787917" y1="0.0" x2="76.66060094787917" y2="305.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="133.02868988014325" y1="0.0" x2="133.02868988014325" y2="305.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="189.39677881240732" y1="0.0" x2="189.39677881240732" y2="305.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="245.7648677446714" y1="0.0" x2="245.7648677446714" y2="305.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="302.13295667693546" y1="0.0" x2="302.13295667693546" y2="305.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="358.50104560919954" y1="0.0" x2="358.50104560919954" y2="305.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="414.8691345414636" y1="0.0" x2="414.8691345414636" y2="305.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#         <g transform="translate(35.01530667574961 0.0 ) ">
#           <g>
#             <line x1="0.0" y1="287.91974267032276" x2="446.4352643435323" y2="287.91974267032276" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="239.67042817970895" x2="446.4352643435323" y2="239.67042817970895" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="191.42111368909514" x2="446.4352643435323" y2="191.42111368909514" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="143.17179919848132" x2="446.4352643435323" y2="143.17179919848132" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="94.92248470786754" x2="446.4352643435323" y2="94.92248470786754" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="46.673170217253755" x2="446.4352643435323" y2="46.673170217253755" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#       </g>
#       <g clip-path="url(#coLyP02)" clip-bounds-jfx="[rect (35.01530667574961, 0.0), (446.4352643435323, 305.0)]">
#         <g transform="translate(35.01530667574961 0.0 ) ">
#           <g>
#             <g>
#               <line x1="0.0" y1="191.42111368909514" x2="446.43526434353225" y2="191.4211136890951" stroke="rgb(0,0,0)" stroke-opacity="1.0" fill="none" stroke-width="2.2">
#               </line>
#             </g>
#             <g>
#               <g>
#                 <path d="M20.292512015615102 235.16715882725165 L20.292512015615102 235.16715882725165 L23.110916462228488 216.83241932081842 L25.929320908841873 198.49767981438515 L28.74772535545435 236.13214511706394 L31.566129802067735 215.22410883779796 L34.38453424868112 242.24372495254167 L37.202938695294506 249.96361527103988 L40.02134314190789 263.15176123180765 L42.83974758852037 234.84549673064754 L45.65815203513375 209.1125290023202 L48.47655648174714 246.1036701117908 L51.294960928360524 229.37724108837799 L54.11336537497391 235.81048302045983 L56.931769821586386 291.1363636363636 L59.75017426819977 246.74699430499896 L62.56857871481316 248.35530478801942 L65.38698316142654 217.1540814174225 L68.20538760803993 228.0905927019616 L71.0237920546524 213.93746045138158 L73.84219650126579 231.95053786121073 L76.66060094787917 217.4757435140266 L79.47900539449256 219.40571609365114 L82.29740984110595 216.83241932081842 L85.11581428771842 214.58078464458976 L87.93421873433181 247.06865640160305 L90.75262318094519 237.4187935034803 L93.57102762755858 225.1956338325248 L96.38943207417196 251.89358785066443 L99.20783652078444 235.81048302045983 L102.02624096739783 255.11020881670535 L104.84464541401121 241.27873866272938 L107.6630498606246 242.56538704914576 L110.48145430723798 226.80394431554527 L113.29985875385046 227.44726850875344 L116.11826320046384 191.42111368909514 L118.93666764707723 211.04250158194475 L121.75507209369061 237.0971314068762 L124.573476540304 265.0817338114322 L127.39188098691648 247.39031849820714 L130.21028543352986 234.84549673064754 L133.02868988014325 228.7339168951698 L135.84709432

# %% [markdown]
# Questions:Using the findings of the New York Times article and your answers to Questions 1 to 5, discuss whether temperature appears to be more variable over time. Would you advise the government to spend more money on mitigating the effects of extreme weather events?

# %% [markdown]
# The answer:As temperatures change more over time due to global warming, heat extremes are becoming more frequent and damaging. First, I suggest that the government should spend more money to alleviate the impact of extreme weather events on people's lives, such as expanding the urban green area. Second, we will advocate low-carbon travel and life for the people.

# %%
df_co2 = pd.read_csv("D:/python/wu jindi-python_homework/Practical05/wu jindi/data/1_C02-data.csv")
df_co2.head()
# Out:
#    Year  Month  Monthly average  Interpolated   Trend
# 0  1958      3           315.71        315.71  314.62
# 1  1958      4           317.45        317.45  315.29
# 2  1958      5           317.50        317.50  314.71
# 3  1958      6           -99.99        317.10  314.85
# 4  1958      7           315.86        315.86  314.98

# %%
df_co2_june = df_co2.loc[df_co2["Month"] == 6]
df_co2_june.head()
# Out:
#     Year  Month  Monthly average  Interpolated   Trend
# 3   1958      6           -99.99        317.10  314.85
# 15  1959      6           318.15        318.15  315.92
# 27  1960      6           319.59        319.59  317.36
# 39  1961      6           319.77        319.77  317.48
# 51  1962      6           320.55        320.55  318.27

# %%
df_temp_co2 = pd.merge(df_co2_june, df, on="Year")
df_temp_co2[["Year", "Jun", "Trend"]].head()
# Out:
#    Year   Jun   Trend
# 0  1958  0.05  314.85
# 1  1959  0.14  315.92
# 2  1960  0.18  317.36
# 3  1961  0.18  317.48
# 4  1962 -0.13  318.27

# %%
(
    ggplot(df_temp_co2, aes(x="Jun", y="Trend"))
    + geom_point(color="black", size=3)
    + labs(
        title="Scatterplot of temperature anomalies vs carbon dioxide emissions",
        y="Carbon dioxide levels (trend, mole fraction)",
        x="Temperature anomaly (degrees Celsius)",
    )
)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #p9lA3Mf .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #p9lA3Mf .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #p9lA3Mf .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #p9lA3Mf .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# #p9lA3Mf .legend-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #p9lA3Mf .legend-item {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #p9lA3Mf .axis-title-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #p9lA3Mf .axis-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dF8Y7VG .axis-tooltip-text-x {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #p9lA3Mf .axis-title-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #p9lA3Mf .axis-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dF8Y7VG .axis-tooltip-text-y {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #p9lA3Mf .facet-strip-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #p9lA3Mf .facet-strip-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dF8Y7VG .tooltip-text {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dF8Y7VG .tooltip-title {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dF8Y7VG .tooltip-label {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
#
#   </style>
#   <g id="p9lA3Mf">
#     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
#     </path>
#     <g transform="translate(29.5 26.5 ) ">
#       <g>
#         <g transform="translate(29.941816366404606 0.0 ) ">
#           <g>
#             <line x1="24.275371983345238" y1="0.0" x2="24.275371983345238" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="97.83710526620962" y1="0.0" x2="97.83710526620962" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="171.39883854907401" y1="0.0" x2="171.39883854907401" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="244.96057183193838" y1="0.0" x2="244.96057183193838" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="318.52230511480275" y1="0.0" x2="318.52230511480275" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="392.08403839766714" y1="0.0" x2="392.08403839766714" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="465.6457716805315" y1="0.0" x2="465.6457716805315" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#         <g transform="translate(29.941816366404606 0.0 ) ">
#           <g>
#             <line x1="0.0" y1="290.01659923845796" x2="534.0581836335954" y2="290.01659923845796" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="226.35643741075683" x2="534.0581836335954" y2="226.35643741075683" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="162.6962755830557" x2="534.0581836335954" y2="162.6962755830557" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="99.03611375535456" x2="534.0581836335954" y2="99.03611375535456" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="35.37595192765343" x2="534.0581836335954" y2="35.37595192765343" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#       </g>
#       <g clip-path="url(#cSak7lU)" clip-bounds-jfx="[rect (29.941816366404606, 0.0), (534.0581836335954, 321.0)]">
#         <g transform="translate(29.941816366404606 0.0 ) ">
#           <g>
#             <g>
#               <g>
#                 <g >
#                   <circle fill="#000000" stroke="#000000" stroke-opacity="0.0" stroke-width="0.0" cx="116.22753858692572" cy="306.4090909090909" r="3.3000000000000003" />
#                   <circle fill="#000000" stroke="#000000" stroke-opacity="0.0" stroke-width="0.0" cx="149.33031856421468" cy="303.0032722513089" r="3.3000000000000003" />
#                   <circle fill="#000000" stroke="#000000" stroke-opacity="0.0" stroke-width="0.0" cx="164.04266522078757" cy="298.4197405997144" r="3.3000000000000003" />
#                   <circle fill="#000000" stroke="#000000" stroke-opacity="0.0" stroke-width="0.0" cx="164.04266522078757" cy="298.03777962874824" r="3.3000000000000003" />
#                   <circle fill="#000000" stroke="#000000" stroke-opacity="0.0" stroke-width="0.0" cx="50.021978632347775" cy="295.5232032365541" r="3.3000000000000003" />
#                   <circle fill="#000000" stroke="#000000" stroke-opacity="0.0" stroke-width="0.0" cx="83.12475860963674" cy="292.69032603522123" r="3.3000000000000003" />
#                   <circle fill="#000000" stroke="#000000" stroke-opacity="0.0" stroke-width="0.0" cx="64.73432528892064" cy="291.00333174678724" r="3.3000000000000003" />
#                   <circle fill="#000000" stroke="#000000" stroke-opacity="0.0" stroke-width="0.0" cx="24.275371983345238" cy="291.1306520704427" r="3.3000000000000003" />
#                   <circle fill="#000000" stroke="#000000" stroke-opacity="0.0" stroke-width="0.0" cx="119.90562525106893" cy="285.17842693955265" r="3.3000000000000003" />
#                   <circle fill="#000000" stroke="#000000" stroke-opacity="0.0" stroke-width="0.0" cx="75.76858528135031" cy="283.8415635411709" r="3.3000000000000003" />
#                   <circle fill="#000000" stroke="#000000" stroke-opacity="0.0" stroke-width="0.0" cx="83.12475860963674" cy="279.83097334602576" r="3.3000000000000003" />
#                   <circle fill="#000000" stroke="#000000" stroke-opacity="0.0" stroke-width="0.0" cx="83.12475860963674" cy="275.279271775345" r="3.3000000000000003" />
#                   <circle fill="#000000" stroke="#000000" stroke-opacity="0.0" stroke-width="0.0" cx="105.19327859449605" cy="272.4463945740124" r="3.3000000000000003" />

# %%
df_temp_co2[["Jun", "Trend"]].corr(method="pearson")
# Out:
#             Jun     Trend
# Jun    1.000000  0.914371
# Trend  0.914371  1.000000

# %%
(
    ggplot(df_temp_co2, aes(x="Year", y="Jun"))
    + geom_line(size=1)
    + labs(
        title="June temperature anomalies",
    )
    + scale_x_continuous(format="d")
)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pI4EIL3 .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #pI4EIL3 .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pI4EIL3 .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pI4EIL3 .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# #pI4EIL3 .legend-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pI4EIL3 .legend-item {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pI4EIL3 .axis-title-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pI4EIL3 .axis-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dmBlzZ3 .axis-tooltip-text-x {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pI4EIL3 .axis-title-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pI4EIL3 .axis-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dmBlzZ3 .axis-tooltip-text-y {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pI4EIL3 .facet-strip-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pI4EIL3 .facet-strip-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dmBlzZ3 .tooltip-text {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dmBlzZ3 .tooltip-title {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dmBlzZ3 .tooltip-label {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
#
#   </style>
#   <g id="pI4EIL3">
#     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
#     </path>
#     <g transform="translate(29.5 26.5 ) ">
#       <g>
#         <g transform="translate(35.01530667574961 0.0 ) ">
#           <g>
#             <line x1="40.3462901687999" y1="0.0" x2="40.3462901687999" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="121.85394707546402" y1="0.0" x2="121.85394707546402" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="203.36160398212814" y1="0.0" x2="203.36160398212814" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="284.86926088879227" y1="0.0" x2="284.86926088879227" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="366.3769177954564" y1="0.0" x2="366.3769177954564" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="447.8845747021205" y1="0.0" x2="447.8845747021205" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#         <g transform="translate(35.01530667574961 0.0 ) ">
#           <g>
#             <line x1="0.0" y1="306.40909090909093" x2="528.9846933242504" y2="306.40909090909093" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="262.1942148760331" x2="528.9846933242504" y2="262.1942148760331" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="217.9793388429752" x2="528.9846933242504" y2="217.9793388429752" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="173.76446280991738" x2="528.9846933242504" y2="173.76446280991738" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="129.5495867768595" x2="528.9846933242504" y2="129.5495867768595" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="85.33471074380168" x2="528.9846933242504" y2="85.33471074380168" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="41.119834710743845" x2="528.9846933242504" y2="41.119834710743845" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#       </g>
#       <g clip-path="url(#cAJacVf)" clip-bounds-jfx="[rect (35.01530667574961, 0.0), (528.9846933242504, 321.0)]">
#         <g transform="translate(35.01530667574961 0.0 ) ">
#           <g>
#             <g>
#               <g>
#                 <path d="M24.04475878746598 251.1404958677686 L24.04475878746598 251.1404958677686 L32.19552447813294 231.24380165289259 L40.3462901687999 222.40082644628103 L48.497055859465036 222.40082644628103 L56.647821550131994 290.93388429752065 L64.79858724079895 271.03719008264466 L72.94935293146591 282.0909090909091 L81.10011862213105 306.40909090909093 L89.25088431279801 248.92975206611573 L97.40165000346497 275.4586776859504 L105.5524156941301 271.03719008264466 L113.70318138479706 271.03719008264466 L121.85394707546402 257.7727272727273 L130.00471276612916 293.1446280991736 L138.15547845679612 284.301652892562 L146.30624414746308 226.8223140495868 L154.45700983812822 301.9876033057851 L162.60777552879517 279.8801652892562 L170.75854121946213 306.40909090909093 L178.9093069101291 213.55785123966945 L187.06007260079423 293.1446280991736 L195.2108382914612 246.71900826446281 L203.36160398212814 220.19008264462812 L211.51236967279328 200.2933884297521 L219.66313536346024 259.9834710743802 L227.8139010541272 237.87603305785126 L235.96466674479234 242.29752066115705 L244.1154324354593 262.1942148760331 L252.26619812612626 231.24380165289259 L260.4169638167932 226.8223140495868 L268.56772950745835 173.76446280991738 L276.7184951981253 209.13636363636365 L284.86926088879227 156.07851239669424 L293.0200265794574 158.28925619834715 L301.17079227012437 253.3512396694215 L309.3215579607913 213.55785123966945 L317.47232365145646 171.5537190082645 L325.6230893421234 151.65702479338847 L333.7738550327904 206.92561983471077 L341.9246207234555 153.86776859504135 L350.0753864141225 103.02066115702485 L358.22615210478943 187.02892561983472 L366.3769177954564 164.92148760330582 L374.52768348612153 149.44628099173556 L382.6784491767885 111.86363636363637 L390.82921486745545 142.8140495867769 L398.9799805581206 160.50000000000003 L407.13074624878755 89.75619834710747 L415.2815119394545 85.33471074380168 L423.43227763011964 118.49586776859508 L431.5830433207866 127.33884297520666 L439.73380901145356 116.28512396694217 L447.

# %%
base_plot = ggplot(df_temp_co2) + scale_x_continuous(format="d")
plot_p = (
    base_plot
    + geom_line(aes(x="Year", y="Jun"), size=1)
    + labs(title="June temperature anomalies")
)
plot_q = (
    base_plot
    + geom_line(aes(x="Year", y="Trend"), size=1)
    + labs(title="Carbon dioxide emissions")
)
gggrid([plot_p, plot_q], ncol=2)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="900.0" height="400.0">
#   <g id="pAgsMwJ">
#     <rect x="0.0" y="0.0" height="400.0" width="900.0" fill="rgb(255,255,255)" fill-opacity="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0">
#     </rect>
#   </g>
#   <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="448.0" height="400.0" x="0.0" y="0.0">
#     <style type="text/css">
#     .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pXpGu7g .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #pXpGu7g .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pXpGu7g .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pXpGu7g .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# #pXpGu7g .legend-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pXpGu7g .legend-item {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pXpGu7g .axis-title-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pXpGu7g .axis-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dEKNk9l .axis-tooltip-text-x {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pXpGu7g .axis-title-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pXpGu7g .axis-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dEKNk9l .axis-tooltip-text-y {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pXpGu7g .facet-strip-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pXpGu7g .facet-strip-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dEKNk9l .tooltip-text {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dEKNk9l .tooltip-title {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dEKNk9l .tooltip-label {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
#
#     </style>
#     <g id="pXpGu7g">
#       <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L448.0 400.0 L448.0 0.0 Z">
#       </path>
#       <g transform="translate(29.5 26.5 ) ">
#         <g>
#           <g transform="translate(35.01530667574961 0.0 ) ">
#             <g>
#               <line x1="28.753069829816013" y1="0.0" x2="28.753069829816013" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#               </line>
#               <line x1="86.84007958701841" y1="0.0" x2="86.84007958701841" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#               </line>
#               <line x1="144.92708934422262" y1="0.0" x2="144.92708934422262" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#               </line>
#               <line x1="203.01409910142502" y1="0.0" x2="203.01409910142502" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#               </line>
#               <line x1="261.10110885862923" y1="0.0" x2="261.10110885862923" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#               </line>
#               <line x1="319.1881186158316" y1="0.0" x2="319.1881186158316" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#               </line>
#             </g>
#           </g>
#           <g transform="translate(35.01530667574961 0.0 ) ">
#             <g>
#               <line x1="0.0" y1="306.40909090909093" x2="376.9846933242504" y2="306.40909090909093" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#               </line>
#               <line x1="0.0" y1="262.1942148760331" x2="376.9846933242504" y2="262.1942148760331" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#               </line>
#               <line x1="0.0" y1="217.9793388429752" x2="376.9846933242504" y2="217.9793388429752" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#               </line>
#               <line x1="0.0" y1="173.76446280991738" x2="376.9846933242504" y2="173.76446280991738" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#               </line>
#               <line x1="0.0" y1="129.5495867768595" x2="376.9846933242504" y2="129.5495867768595" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#               </line>
#               <line x1="0.0" y1="85.33471074380168" x2="376.9846933242504" y2="85.33471074380168" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#               </line>
#               <line x1="0.0" y1="41.119834710743845" x2="376.9846933242504" y2="41.119834710743845" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#               </line>
#             </g>
#           </g>
#         </g>
#         <g clip-path="url(#c8cDfKi)" clip-bounds-jfx="[rect (35.01530667574961, 0.0), (376.9846933242504, 321.0)]">
#           <g transform="translate(35.01530667574961 0.0 ) ">
#             <g>
#               <g>
#                 <g>
#                   <path d="M17.13566787837408 251.1404958677686 L17.13566787837408 251.1404958677686 L22.944368854094137 231.24380165289259 L28.753069829816013 222.40082644628103 L34.56177080553607 222.40082644628103 L40.37047178125613 290.93388429752065 L46.179172756976186 271.03719008264466 L51.987873732696244 282.0909090909091 L57.7965747084163 306.40909090909093 L63.60527568413636 248.92975206611573 L69.41397665985824 275.4586776859504 L75.2226776355783 271.03719008264466 L81.03137861129835 271.03719008264466 L86.84007958701841 257.7727272727273 L92.64878056273847 293.1446280991736 L98.45748153845852 284.301652892562 L104.2661825141804 226.8223140495868 L110.07488348990046 301.9876033057851 L115.88358446562052 279.8801652892562 L121.69228544134057 306.40909090909093 L127.50098641706063 213.55785123966945 L133.3096873927807 293.1446280991736 L139.11838836850075 246.71900826446281 L144.92708934422262 220.19008264462812 L150.73579031994268 200.2933884297521 L156.54449129566274 259.9834710743802 L162.3531922713828 237.87603305785126 L168.16189324710285 242.29752066115705 L173.9705942228229 262.1942148760331 L179.77929519854297 231.24380165289259 L185.58799617426484 226.8223140495868 L191.3966971499849 173.76446280991738 L197.20539812570496 209.13636363636365 L203.01409910142502 156.07851239669424 L208.82280007714508 158.28925619834715 L214.63150105286513 253.3512396694215 L220.440202028587 213.55785123966945 L226.24890300430707 171.5537190082645 L232.05760398002712 151.65702479338847 L237.86630495574718 206.92561983471077 L243.67500593146724 153.8677685

# %% [markdown]
# Extra practice: Choose two months and add the CO2 trend data to the temperature dataset from Part 1.1, making sure that the data corresponds to the correct year. Create a separate chart for each month.

# %% [markdown]
# The answer:

# %%
df_co2_june = df_co2.loc[df_co2["Month"] == 3]
df_co2_june.head()
# Out:
#     Year  Month  Monthly average  Interpolated   Trend
# 0   1958      3           315.71        315.71  314.62
# 12  1959      3           316.71        316.71  315.62
# 24  1960      3           317.58        317.58  316.49
# 36  1961      3           318.54        318.54  317.47
# 48  1962      3           319.68        319.68  318.57

# %%
df_temp_co2 = pd.merge(df_co2_june, df, on="Year")
df_temp_co2[["Year", "Mar", "Trend"]].head()
# Out:
#    Year   Mar   Trend
# 0  1958  0.16  314.62
# 1  1959  0.33  315.62
# 2  1960 -0.40  316.49
# 3  1961  0.22  317.47
# 4  1962  0.30  318.57

# %%
(
    ggplot(df_temp_co2, aes(x="Mar", y="Trend"))
    + geom_point(color="red", size=3)
    + labs(
        title="Scatterplot of temperature anomalies vs carbon dioxide emissions",
        y="Carbon dioxide levels (trend, mole fraction)",
        x="Temperature anomaly (degrees Celsius)",
    )
)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pEA9pG5 .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #pEA9pG5 .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pEA9pG5 .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pEA9pG5 .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# #pEA9pG5 .legend-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pEA9pG5 .legend-item {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pEA9pG5 .axis-title-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pEA9pG5 .axis-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #da6StwL .axis-tooltip-text-x {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pEA9pG5 .axis-title-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pEA9pG5 .axis-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #da6StwL .axis-tooltip-text-y {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pEA9pG5 .facet-strip-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pEA9pG5 .facet-strip-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #da6StwL .tooltip-text {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #da6StwL .tooltip-title {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #da6StwL .tooltip-label {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
#
#   </style>
#   <g id="pEA9pG5">
#     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
#     </path>
#     <g transform="translate(29.5 26.5 ) ">
#       <g>
#         <g transform="translate(29.941816366404606 0.0 ) ">
#           <g>
#             <line x1="3.0741737446157913" y1="0.0" x2="3.0741737446157913" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="109.08016493826317" y1="0.0" x2="109.08016493826317" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="215.08615613191054" y1="0.0" x2="215.08615613191054" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="321.0921473255579" y1="0.0" x2="321.0921473255579" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="427.0981385192053" y1="0.0" x2="427.0981385192053" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="533.1041297128527" y1="0.0" x2="533.1041297128527" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#         <g transform="translate(29.941816366404606 0.0 ) ">
#           <g>
#             <line x1="0.0" y1="289.15464736384615" x2="534.0581836335954" y2="289.15464736384615" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="225.01173455624485" x2="534.0581836335954" y2="225.01173455624485" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="160.86882174864377" x2="534.0581836335954" y2="160.86882174864377" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="96.72590894104246" x2="534.0581836335954" y2="96.72590894104246" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="32.582996133441384" x2="534.0581836335954" y2="32.582996133441384" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#       </g>
#       <g clip-path="url(#cfSRkBP)" clip-bounds-jfx="[rect (29.941816366404606, 0.0), (534.0581836335954, 321.0)]">
#         <g transform="translate(29.941816366404606 0.0 ) ">
#           <g>
#             <g>
#               <g>
#                 <g >
#                   <circle fill="#ff0000" stroke="#ff0000" stroke-opacity="0.0" stroke-width="0.0" cx="143.00208212023034" cy="306.40909090909076" r="3.3000000000000003" />
#                   <circle fill="#ff0000" stroke="#ff0000" stroke-opacity="0.0" stroke-width="0.0" cx="179.04411912607043" cy="303.2019452687107" r="3.3000000000000003" />
#                   <circle fill="#ff0000" stroke="#ff0000" stroke-opacity="0.0" stroke-width="0.0" cx="24.275371983345266" cy="300.41172856158005" r="3.3000000000000003" />
#                   <circle fill="#ff0000" stroke="#ff0000" stroke-opacity="0.0" stroke-width="0.0" cx="155.722801063468" cy="297.26872583400757" r="3.3000000000000003" />
#                   <circle fill="#ff0000" stroke="#ff0000" stroke-opacity="0.0" stroke-width="0.0" cx="172.6837596544516" cy="293.7408656295896" r="3.3000000000000003" />
#                   <circle fill="#ff0000" stroke="#ff0000" stroke-opacity="0.0" stroke-width="0.0" cx="85.75884687566074" cy="293.3560081527439" r="3.3000000000000003" />
#                   <circle fill="#ff0000" stroke="#ff0000" stroke-opacity="0.0" stroke-width="0.0" cx="41.236330574328846" cy="290.59786290201714" r="3.3000000000000003" />
#                   <circle fill="#ff0000" stroke="#ff0000" stroke-opacity="0.0" stroke-width="0.0" cx="87.87896669953369" cy="290.27714833797927" r="3.3000000000000003" />
#                   <circle fill="#ff0000" stroke="#ff0000" stroke-opacity="0.0" stroke-width="0.0" cx="109.08016493826317" cy="285.4343584210051" r="3.3000000000000003" />
#                   <circle fill="#ff0000" stroke="#ff0000" stroke-opacity="0.0" stroke-width="0.0" cx="157.84292088734097" cy="283.63835686239236" r="3.3000000000000003" />
#                   <circle fill="#ff0000" stroke="#ff0000" stroke-opacity="0.0" stroke-width="0.0" cx="202.36543718867284" cy="280.8481401552617" r="3.3000000000000003" />
#                   <circle fill="#ff0000" stroke="#ff0000" stroke-opacity="0.0" stroke-width="0.0" cx="66.67776846080422" cy="275.01113508977005" r="3.3000000000000003" />
#                   <circle fill="#ff0000" stroke="#ff0000" stroke-opacity="0.0" stroke-width="0.0" cx="94.23932617115253" cy="270.9059886700836" r="3.3000000000000003" />
#                   <circle fill="#ff0000" stroke="#ff0000" stroke-opacity="0.0" stroke-width="0.0" cx="49.71680986982063" cy="270.1042022599886" r="3.3000000000000003" />

# %%
df_co2_june = df_co2.loc[df_co2["Month"] == 9]
df_co2_june.head()
# Out:
#     Year  Month  Monthly average  Interpolated   Trend
# 6   1958      9           313.20        313.20  315.91
# 18  1959      9           313.84        313.84  316.55
# 30  1960      9           314.16        314.16  316.87
# 42  1961      9           314.80        314.80  317.49
# 54  1962      9           316.26        316.26  319.03

# %%
df_temp_co2 = pd.merge(df_co2_june, df, on="Year")
df_temp_co2[["Year", "Sep", "Trend"]].head()
# Out:
#    Year   Sep   Trend
# 0  1958  0.07  315.91
# 1  1959  0.13  316.55
# 2  1960  0.12  316.87
# 3  1961 -0.03  317.49
# 4  1962 -0.02  319.03

# %%
(
    ggplot(df_temp_co2, aes(x="Sep", y="Trend"))
    + geom_point(color="blue", size=3)
    + labs(
        title="Scatterplot of temperature anomalies vs carbon dioxide emissions",
        y="Carbon dioxide levels (trend, mole fraction)",
        x="Temperature anomaly (degrees Celsius)",
    )
)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pxYbEBD .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #pxYbEBD .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pxYbEBD .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pxYbEBD .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# #pxYbEBD .legend-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pxYbEBD .legend-item {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pxYbEBD .axis-title-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pxYbEBD .axis-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dyYh32Z .axis-tooltip-text-x {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pxYbEBD .axis-title-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pxYbEBD .axis-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dyYh32Z .axis-tooltip-text-y {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pxYbEBD .facet-strip-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pxYbEBD .facet-strip-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dyYh32Z .tooltip-text {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dyYh32Z .tooltip-title {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dyYh32Z .tooltip-label {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
#
#   </style>
#   <g id="pxYbEBD">
#     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
#     </path>
#     <g transform="translate(29.5 26.5 ) ">
#       <g>
#         <g transform="translate(29.941816366404606 0.0 ) ">
#           <g>
#             <line x1="50.16910209891351" y1="0.0" x2="50.16910209891351" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="114.90342738783417" y1="0.0" x2="114.90342738783417" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="179.63775267675481" y1="0.0" x2="179.63775267675481" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="244.3720779656755" y1="0.0" x2="244.3720779656755" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="309.10640325459616" y1="0.0" x2="309.10640325459616" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="373.8407285435168" y1="0.0" x2="373.8407285435168" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="438.57505383243745" y1="0.0" x2="438.57505383243745" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="503.309379121358" y1="0.0" x2="503.309379121358" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#         <g transform="translate(29.941816366404606 0.0 ) ">
#           <g>
#             <line x1="0.0" y1="292.94258562153186" x2="534.0581836335954" y2="292.94258562153186" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="260.0171448206538" x2="534.0581836335954" y2="260.0171448206538" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="227.09170401977576" x2="534.0581836335954" y2="227.09170401977576" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="194.1662632188977" x2="534.0581836335954" y2="194.1662632188977" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="161.2408224180199" x2="534.0581836335954" y2="161.2408224180199" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="128.31538161714184" x2="534.0581836335954" y2="128.31538161714184" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="95.38994081626379" x2="534.0581836335954" y2="95.38994081626379" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="62.46450001538574" x2="534.0581836335954" y2="62.46450001538574" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="29.539059214507688" x2="534.0581836335954" y2="29.539059214507688" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#       </g>
#       <g clip-path="url(#c24mLf9)" clip-bounds-jfx="[rect (29.941816366404606, 0.0), (534.0581836335954, 321.0)]">
#         <g transform="translate(29.941816366404606 0.0 ) ">
#           <g>
#             <g>
#               <g>
#                 <g >
#                   <circle fill="#0000ff" stroke="#0000ff" stroke-opacity="0.0" stroke-width="0.0" cx="137.5604412389564" cy="306.409090909091" r="3.3000000000000003" />
#                   <circle fill="#0000ff" stroke="#0000ff" stroke-opacity="0.0" stroke-width="0.0" cx="156.98073882563259" cy="304.30186269783485" r="3.3000000000000003" />
#                   <circle fill="#0000ff" stroke="#0000ff" stroke-opacity="0.0" stroke-width="0.0" cx="153.74402256118657" cy="303.24824859220666" r="3.3000000000000003" />
#                   <circle fill="#0000ff" stroke="#0000ff" stroke-opacity="0.0" stroke-width="0.0" cx="105.19327859449608" cy="301.20687126255234" r="3.3000000000000003" />
#                   <circle fill="#0000ff" stroke="#0000ff" stroke-opacity="0.0" stroke-width="0.0" cx="108.42999485894211" cy="296.1363533792171" r="3.3000000000000003" />
#                   <circle fill="#0000ff" stroke="#0000ff" stroke-opacity="0.0" stroke-width="0.0" cx="156.98073882563259" cy="296.03757705681437" r="3.3000000000000003" />
#                   <circle fill="#0000ff" stroke="#0000ff" stroke-opacity="0.0" stroke-width="0.0" cx="24.275371983345252" cy="294.3913050167705" r="3.3000000000000003" />
#                   <circle fill="#0000ff" stroke="#0000ff" stroke

# %% [markdown]
# Questions:What do your charts and the correlation coefficients suggest about the relationship between CO2 levels and temperature anomalies?

# %% [markdown]
# The answer:CO2 levels and temperature have strongly correlated with each other.

# %% [markdown]
# Questions:Consider the example of spurious correlation described above.
# Questions:(1)In your own words, explain spurious correlation and the difference between correlation and causation.
# The answer:Spurious correlation: When two things seem linked but aren't really, often due to a hidden factor.Correlation vs causation: Correlation shows a link, but causation means one thing causes another.
#
# Questions:(2)Give an example of spurious correlation, similar to the one above, for either CO2 levels or temperature anomalies.
# The answer:
# Example: CO2 Levels and Stock Market Performance.It might seem that there's a correlation between rising CO2 levels in the atmosphere and improved stock market performance. However, this doesn't mean that CO2 levels are directly causing the stock market to rise. Instead, both could be influenced by a common factor, such as economic growth. As economies grow, they often emit more CO2 and also tend to have better stock market performance.
#
# Questions:(3)Choose an example of spurious correlation from Tyler Vigen’s website. Explain whether you think it is a coincidence, or whether this correlation could be due to one or more other variables.
# The answer:An example is the correlation between the number of Nicolas Cage films released in a year and the number of people who die by falling into swimming pools.Is it a coincidence?Yes, it is likely a coincidence.Could it be due to one or more other variables?It could be due to the fact that both of these events are influenced by broader societal trends or random fluctuations that are not directly related to each other. For instance, the number of Nicolas Cage films released might be influenced by the film industry's production schedule, while the number of swimming pool accidents could be influenced by factors such as weather conditions, safety regulations, and public awareness. There is no plausible mechanism through which the release of Nicolas Cage films could cause an increase in swimming pool accidents, or vice versa. Therefore, it is reasonable to conclude that this correlation is spurious and due to chance or other unobserved variables.
